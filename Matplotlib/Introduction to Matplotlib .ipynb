# %% [markdown]
# ## Introduction to Matplotlib

# %%
# %config Completer.use_jedi = False
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-whitegrid')

# %%
x = [1,2,3,4]
y = [5,4,6,2]
plt.plot(x,y, color ='red');
#phải thêm dấu ; ở cuối để bỏ [<matplotlib.lines.Line2D at 0x2cae4d3b130>]

# %% [markdown]
# ### Pyplot API vs Object - Oriented (OO) API
# * Pyplot API -> simple, quick
# * OO API -> Advanced

# %%
x = np.linspace(0,10,1000)
plt.plot(x,np.sin(x),linestyle='dashed',label ='sin(x)' );
plt.plot(x,np.cos(x), color='red',label ='cos(x)');

plt.title('Sin(x) and Cos(x)');

plt.xlabel('Bien X')
plt.ylabel('F(x)')

#plt.xlim([0,4])
#plt.ylim([-0.7,0.6])

#plt.axis([0,4,-0.7,0.6]) #[xmin,xmax,ymin,ymax]

plt.legend();

# %% [markdown]
# ## Object-Oriented API

# %%
x = [1,2,3,4]
y = [11,22,33,44]
#setup
fig, ax = plt.subplots(figsize=(5,5)) #figure size = Width & Height of the plot

#plot the data
ax.plot(x,y);

ax.set(title = 'A simple plot',xlabel='x-axis',ylabel='y-axis');

# %% [markdown]
# ### Most common types of Matplotlib plots
# * line
# * scatter
# * bar
# * hist
# * subplots

# %%
# create an array
x = np.linspace(0,10,100)
x[:5]
# Out:
# array([0.       , 0.1010101, 0.2020202, 0.3030303, 0.4040404])

# %%
# OO API plot a line chart
fig, ax = plt.subplots()
ax.plot(x,x**3);

# %% [markdown]
# ### Scatter

# %%
# Pyplot API
plt.scatter(x,np.exp(x)); #y=e^(x)

# %%
# OO API

#Prepare new data
rng = np.random.RandomState(0)
x = rng.random(100)
y = rng.random(100)

colors = rng.rand(100)
sizes = 100*rng.rand(100)

fig, ax = plt.subplots()
img1 = ax.scatter(x,y, s=sizes, c=colors, cmap='viridis', alpha=0.3);
# moi cham co mau va size khac nhau
fig.colorbar(img1);
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_11316\799880500.py:14: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   fig.colorbar(img1);

# %% [markdown]
# ### Bar chart
# * Vertical
# * Horizontal

# %%
# prepare data from a python dictionary
soft_drink_prices = {'Coke':10, 'Pepsi':12,'Sprite':8}

fig, ax = plt.subplots()
ax.bar(soft_drink_prices.keys(), soft_drink_prices.values())
ax.set(title="Bach hoa Xanh's Soft Drink Prices", ylabel="Price");

# %%
fig, ax = plt.subplots()
ax.barh(list(soft_drink_prices.keys()), list(soft_drink_prices.values()));
#barh k nhan dictionary

# %% [markdown]
# ### Histogram

# %%
#Prepare data
np.random.seed(42)
student_height = np.random.normal(170,10,250) #(trung binh, do lech, tong)
student_height[:10]
# Out:
# array([174.96714153, 168.61735699, 176.47688538, 185.23029856,
#        167.65846625, 167.65863043, 185.79212816, 177.67434729,
#        165.30525614, 175.42560044])

# %%
# Pyplot API
plt.hist(student_height, bins = 30);
#bins chia nho khoang cach

# %% [markdown]
# ### Subplots

# %%
# Option 1:
fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))

# %%
#Plot data to each axis
fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))

ax1.plot(x,x/2);
ax1.plot(x,x*2);

ax2.scatter(np.random.random(10), np.random.random(10));

ax3.bar(soft_drink_prices.keys(), soft_drink_prices.values());

ax4.hist(student_height, bins = 30);

# %%
#Option 2:
fig. ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5));

# %%
#Plot data to each axis
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))

ax[0,0].plot(x,x/2);
ax[0,0].plot(x,x*2);

ax[0,1].scatter(np.random.random(10), np.random.random(10));

ax[1,0].bar(soft_drink_prices.keys(), soft_drink_prices.values());

ax[1,1].hist(student_height, bins = 30);
